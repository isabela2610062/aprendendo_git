# %% [markdown]
# Estudo guiado de git
# ====================
#
# **Autor:** Daniel R. Cassar

# %% [markdown]
# Este notebook apresenta algumas perguntas para você responder durante a aula de Git da disciplina de Práticas em Ciência de Dados. A ideia é que você responda estas questões com suas palavras enquanto assiste a aula ou logo após para sedimentar seu conhecimento.
#
# Desta forma, este notebook não é um notebook didático, mas sim um guia para seus estudos.

# %% [markdown]
# ## Perguntas para estudo guiado

# %% [markdown]
# 1.  O que significa versionamento de código e para que serve isso?
#
#    Cada vez que um documento é mudado e salvo é criado uma versão e isso ajuda a entender o andamento do projeto e para não haver perdas muito significante
#
# 3.  O que é e para que serve o git?
#
#    É um sftware que serve para versionamneto e para salvar versões antigas caso perca algo, ele mostra quem mudou o código, onde e quando foi mudado. Ele mostra todo o historico
#
# 4.  O que é um repositório online de git (como, por exemplo, um repositório no GitHub)? Qual a utilidade de termos um repositório online?
#
# 5.  Para que serve o arquivo de `README`? Quais são as boas práticas de um arquivo `README`?
#
# 6.  Para que serve o arquivo `LICENSE`?
#
# 7.  Para que serve o arquivo `.gitignore`?
#
#    Ele mostra para o python a linguagem que o sistema está usando e mostra pro git os arquivos de texto(com as linguagem de propragamções) que não devem ser subidos já que tem linguagem diferentes da selecionada
#
# 9.  O que faz o comando `git clone`?
#
# 10.  O que faz o comando `git status`?
#
# 11.  O que faz o comando `git add`? Como adicionar apenas um arquivo com o comando `git add`? Como adicionar todos os arquivos com o comando `git add`?
#
# 12. O que faz o comando `git commit`? Qual a diferença entre o `git add` e o `git commit`?
#
# 13. O que faz o comando `git push`?
#
# 14. O que faz o comando `git pull`? Quando devemos utilizá-lo?
#
# 15. Para que serve criar um ramo (*branch*) novo? Em qual situação você se vê ramificando seu repositório?
#
# 16. O que faz o comando `git checkout`?
#
# 17. O que é um fork?
#
# 18. O que é um *pull request*?
#
# 19. Quero contribuir para um repositório que não sou o dono, como fazer isso utilizando de fork e *pull request*?

# %% [markdown]
# ## Material para estudo

# %% [markdown]
# Livro Pro Git: [https://git-scm.com/book/en/v2](https://git-scm.com/book/en/v2). A versão em português ainda não está completa, mas já foi iniciada: [https://git-scm.com/book/pt-br/v2](https://git-scm.com/book/pt-br/v2).
#
# Vídeo &ldquo;O que é Git e GitHub?&rdquo; [https://www.youtube.com/watch?v=DqTITcMq68k](https://www.youtube.com/watch?v=DqTITcMq68k).
#
# Vídeo &ldquo;Como usar Git e GitHub?&rdquo; [https://www.youtube.com/watch?v=UBAX-13g8OM&t=31s](https://www.youtube.com/watch?v=UBAX-13g8OM&t=31s).
#
# Vídeo em Inglês &ldquo;Git & GitHub Crash Course for Beginners&rdquo; [https://youtu.be/mAFoROnOfHs](https://youtu.be/mAFoROnOfHs)
#
# Tutorial interativo visual para aprender todas as estratégias para ramificar seu repositório: [https://learngitbranching.js.org/?locale=pt_BR](https://learngitbranching.js.org/?locale=pt_BR).
#
# Problemas comuns e possíveis soluções: [https://dangitgit.com/pt_BR](https://dangitgit.com/pt_BR).
#
# Git Cheat Sheet: [https://education.github.com/git-cheat-sheet-education.pdf](https://education.github.com/git-cheat-sheet-education.pdf)

# %% [markdown]
# ## XKCD relevante

# %% [markdown]
# ![img](https://imgs.xkcd.com/comics/git.png)
#
# `Imagem: Git (XKCD) disponível em https://xkcd.com/1597`
